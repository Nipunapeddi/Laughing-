# %% [markdown]
# <a href="https://colab.research.google.com/github/Nipunapeddi/Laughing-/blob/main/calender_agent_week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.oauth2 import service_account
from googleapiclient.discovery import build

SCOPES = ['https://www.googleapis.com/auth/calendar.readonly']

SERVICE_ACCOUNT_FILE = '/content/mindful-furnace-488916-t9-9325808654ef.json'

creds = service_account.Credentials.from_service_account_file(
    SERVICE_ACCOUNT_FILE,
    scopes=SCOPES
)

service = build('calendar', 'v3', credentials=creds)

events_result = service.events().list(
    calendarId='peddinipuna@gmail.com',
    maxResults=5,
    singleEvents=True,
    orderBy='startTime'
).execute()

events = events_result.get('items', [])

if not events:
    print("No upcoming events found.")
else:
    for event in events:
        print(event['summary'], event['start'])
# Out:
# Learning reminder {'dateTime': '2025-06-02T10:00:00+05:30', 'timeZone': 'Asia/Kolkata'}
# Learning reminder {'dateTime': '2025-06-03T10:00:00+05:30', 'timeZone': 'Asia/Kolkata'}
# Learning reminder {'dateTime': '2025-06-04T10:00:00+05:30', 'timeZone': 'Asia/Kolkata'}
# Learning reminder {'dateTime': '2025-06-05T10:00:00+05:30', 'timeZone': 'Asia/Kolkata'}
# Learning reminder {'dateTime': '2025-06-06T10:00:00+05:30', 'timeZone': 'Asia/Kolkata'}
